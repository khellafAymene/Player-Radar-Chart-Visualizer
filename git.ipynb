# %%
# !git status
# !git add . ':!git.ipynb'
# !git commit -m "first commit"
# !git push A main
# Out:
# On branch main
# nothing to commit, working tree clean
# On branch main
# nothing to commit, working tree clean
# To https://github.com/khellafAymene/Player-Radar-Chart-Visualizer.git
#    e9b0f23..611159e  main -> main

# %%
# !git add .
# !git commit -m "first commit"
# !git push A main --force
# Out:
# ...
# [main a3945f0] first commit
#  1 file changed, 85 insertions(+)
#  create mode 100644 git.ipynb
# To https://github.com/khellafAymene/Player-Radar-Chart-Visualizer.git
#    0b95659..a3945f0  main -> main

# %%
# !git rm --cached git.ipynb
# !git commit -m "remove file"
# !git push A main
# Out:
# rm 'git.ipynb'
# [main 0b95659] remove file
#  1 file changed, 57 deletions(-)
#  delete mode 100644 git.ipynb
# To https://github.com/khellafAymene/Player-Radar-Chart-Visualizer.git
#    107a6dc..0b95659  main -> main
